# %%
import pandas as pd

# %%
dt1=pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
dt1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
dt1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
dt1.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
dt1.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
dt1.dtypes=='int64'
# Out:
# order_id               True
# quantity               True
# item_name             False
# choice_description    False
# item_price            False
# dtype: bool

# %%
nul=dt1['choice_description'][dt1['choice_description'].isnull()==True]

# %%
nul
# Out:
# 0       NaN
# 3       NaN
# 6       NaN
# 10      NaN
# 14      NaN
#        ...
# 4600    NaN
# 4605    NaN
# 4613    NaN
# 4614    NaN
# 4616    NaN
# Name: choice_description, Length: 1246, dtype: object

# %%
len(nul)
# Out:
# 1246

# %%
dt1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
dt1['choice_description']= dt1['choice_description'].str.split("", n = 2, expand = True)

# %%
dt1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#      choice_description item_price
# 0                   NaN     $2.39
# 1                           $3.39
# 2                           $3.39
# 3                   NaN     $2.39
# ...

# %%
dt1['item_price']=dt1['item_price'].replace('\$','',regex=True).astype(float)

# %%
dt1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
dt1[dt1['quantity']==max(dt1['quantity'])]['order_id']
# Out:
# (3598    1443
#  Name: order_id, dtype: int64,
#  ['item_name'])

# %%
dt1[dt1['item_price']==max(dt1['item_price'])]['item_name']
# Out:
# 3598    Chips and Fresh Tomato Salsa
# Name: item_name, dtype: object

# %%
dt1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
f = dt1.drop_duplicates(['item_name','quantity'])
# select only the products with quantity equals to 1
p= f[f.quantity == 1]
# select only the item_name and item_price columns
price_per_item = p[['item_name', 'item_price']]
# sort the values from the most to less expensive
price_per_item.sort_values(by = "item_price", ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
dt2=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt',sep=' ')

# %%
dt2
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
dt2.dtypes
# Out:
# name         object
# calories      int64
# sodium        int64
# alcohol     float64
# cost        float64
# dtype: object

# %%
dt2.describe()
# Out:
#          calories     sodium    alcohol       cost
# count   20.000000  20.000000  20.000000  20.000000
# mean   132.550000  14.950000   4.240000   0.494500
# std     30.283702   6.581273   1.087924   0.144858
# min     68.000000   6.000000   0.900000   0.280000
# 25%    110.250000   9.500000   4.175000   0.427500
# 50%    144.000000  15.000000   4.600000   0.435000
# 75%    150.250000  19.000000   4.900000   0.485000
# max    175.000000  27.000000   5.500000   0.790000

# %%
dt2.columns
# Out:
# Index(['name', 'calories', 'sodium', 'alcohol', 'cost'], dtype='object')

# %%
dt2[]
# Out:
#   File "<ipython-input-78-8ea88f9275d0>", line 1
#     dt2[]
#         ^
# SyntaxError: invalid syntax

# %%
dt2[dt2['calories']==max(dt2['calories'])]['name']
# Out:
# 6    Augsberger
# Name: name, dtype: object

# %%
dt2
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
g1=dt2[dt2.dtypes[dt2.dtypes=='int64'].index]

# %%
g1
# Out:
#     calories  sodium
# 0        144      15
# 1        151      19
# 2        157      15
# 3        170       7
# 4        152      11
# 5        145      23
# 6        175      24
# 7        149      27
# 8         99      10
# 9        113       8
# 10       140      18
# 11       102      15
# 12       135      11
# 13       150      19
# 14       149       6
# 15        68      15
# 16       139      19
# 17       144      24
# 18        72       6
# 19        97       7

# %%
g1.describe()
# Out:
#          calories     sodium
# count   20.000000  20.000000
# mean   132.550000  14.950000
# std     30.283702   6.581273
# min     68.000000   6.000000
# 25%    110.250000   9.500000
# 50%    144.000000  15.000000
# 75%    150.250000  19.000000
# max    175.000000  27.000000

# %%
d1=dt2[dt2['calories']>=150]['name'] #name of alcohal where calories are greater than or equal to 150

# %%
d1
# Out:
# 1         Schlitz
# 2       Lowenbrau
# 3     Kronenbourg
# 4        Heineken
# 6      Augsberger
# 13          Becks
# Name: name, dtype: object

# %%
dt2.iloc[d1.index]
# Out:
#            name  calories  sodium  alcohol  cost
# 1       Schlitz       151      19      4.9  0.43
# 2     Lowenbrau       157      15      0.9  0.48
# 3   Kronenbourg       170       7      5.2  0.73
# 4      Heineken       152      11      5.0  0.77
# 6    Augsberger       175      24      5.5  0.40
# 13        Becks       150      19      4.7  0.76

# %%
dt3=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
dt3
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
dt3.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
dt3.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
X1=dt3[dt3['Murder']==max(dt3['Murder'])]['Year']

# %%
X1
# Out:
# 31    1991
# Name: Year, dtype: int64

# %%
dt3.iloc[X1.index]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31  1991   318857056  14872900  1911770  12961100   24700         106590
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 31   687730             1092740   3157200        8142200        1661700

# %%
X2=dt3[dt3['Forcible_Rape']>100000]['Year']

# %%
dt3.iloc[X2.index]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 30  1990   318857056  14475600  1820130  12655500   23440         102560
# 31  1991   318857056  14872900  1911770  12961100   24700         106590
# 32  1992   318857056  14438200  1932270  12505900   23760         109060
# 33  1993   318857056  14144800  1926020  12218800   24530         106010
# 34  1994   318857056  13989500  1857670  12131900   23330         102220
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 30   639270             1054860   3073900        7945700        1635900
# 31   687730             1092740   3157200        8142200        1661700
# 32   672480             1126970   2979900        7915200        1610800
# 33   659870             1135610   2834800        7820900        1563100
# 34   618950             1113180   2712800        7879800        1539300

# %%
dt3['Theft']=dt3['Larceny_Theft']+dt3['Vehicle_Theft']

# %%
dt3
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   318857056   3384200   288460   3095700    9110          17190
# 1   1961   318857056   3488000   289390   3198600    8740          17220
# 2   1962   318857056   3752200   301510   3450700    8530          17550
# 3   1963   318857056   4109500   316970   3792500    8640          17650
# 4   1964   318857056   4564600   364220   4200400    9360          21420
# 5   1965   318857056   4739400   387390   4352000    9960          23410
# 6   1966   318857056   5223500   430180   4793300   11040          25820
# 7   1967   318857056   5903400   499930   5403500   12240          27620
# 8   1968   318857056   6720200   595010   6125200   13800          31670
# 9   1969   318857056   7410900   661870   6749000   14760          37170
# 10  1970   318857056   8098000   738820   7359200   16000          37990
# 11  1971   318857056   8588200   816500   7771700   17780          42260
# ...

# %%
dt3.columns.tolist()
# Out:
# ['Year',
#  'Population',
#  'Total',
#  'Violent',
#  'Property',
#  'Murder',
#  'Forcible_Rape',
#  'Robbery',
#  'Aggravated_assault',
#  'Burglary',
#  'Larceny_Theft',
#  'Vehicle_Theft',
#  'Theft']

# %%
dt3["Property"].value_counts() #it counts the value of an attribute
# Out:
# 10345500    1
# 11652000    1
# 10182586    1
# 9955000     1
# 7771700     1
# 9112625     1
# 12218800    1
# 4793300     1
# 12505900    1
# 3198600     1
# 9052743     1
# 12356900    1
# 10174754    1
# 11558175    1
# 10850500    1
# 12063900    1
# 9983568     1
# 10319386    1
# 9843481     1
# 7842200     1
# 12961100    1
# 3095700     1
# 6125200     1
# 12655500    1
# 8650761     1
# 10123400    1
# 12131900    1
# 8277829     1
# 7413900     1
# 9337060     1
# 12024700    1
# 5403500     1
# 10608500    1
# 10252700    1
# 10442862    1
# 10455277    1
# 9278700     1
# 9767915     1
# 11102600    1
# 10437480    1
# 11722700    1
# 11805300    1
# 10944590    1
# 7359200     1
# 11041500    1
# 12605400    1
# 3450700     1
# 12063700    1
# 3792500     1
# 4200400     1
# 10208334    1
# 12061900    1
# 9001992     1
# 6749000     1
# 4352000     1
# Name: Property, dtype: int64

# %%
dt3.dropna(axis=0,inplace=True) #if axis=0 it checks wheather column has NAN values
                                #if axis=1 for Rows

# %%
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   318857056   3384200   288460   3095700    9110          17190
# 1   1961   318857056   3488000   289390   3198600    8740          17220
# 2   1962   318857056   3752200   301510   3450700    8530          17550
# 3   1963   318857056   4109500   316970   3792500    8640          17650
# 4   1964   318857056   4564600   364220   4200400    9360          21420
# 5   1965   318857056   4739400   387390   4352000    9960          23410
# 6   1966   318857056   5223500   430180   4793300   11040          25820
# 7   1967   318857056   5903400   499930   5403500   12240          27620
# 8   1968   318857056   6720200   595010   6125200   13800          31670
# 9   1969   318857056   7410900   661870   6749000   14760          37170
# 10  1970   318857056   8098000   738820   7359200   16000          37990
# 11  1971   318857056   8588200   816500   7771700   17780          42260
# ...

# %%
dt4=pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
dt4
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
dt4.sort_values(by = ['Item','Title'],ascending=True)
# Out:
#          Package          Item  \
# 282         DAAG          ACF1
# 1366   Stat2Data  AHCAvote2017
# 157      carData     AMSsurvey
# 530        Ecdat      Accident
# 1365   Stat2Data   AccordPrice
# ...          ...           ...
# 1239   openintro          yawn
# 1240   openintro         yrbss
# 1241   openintro    yrbss_samp
# 1644   stevedata    yugo_sales
# 251   causaldata          yule
#
#                                                   Title   Rows  Cols  \
# 282                   Aberrant Crypt Foci in Rat Colons     22     2
# 1366  Congressional Votes on American Health Care Ac...    430    11
# 157                   American Math Society Survey Data     24     5
# 530                                      Ship Accidents     40     5
# 1365             Prices of Used Honda Accords (in 2017)     30     3
# ...                                                 ...    ...   ...
# 1239                          Contagiousness of yawning     50     2
# ...

# %%
dt4.groupby(['Rows']).agg(list)
# Out:
#                                                    Package  \
# Rows
# 2        [gap, openintro, reshape2, Stat2Data, Stat2Dat...
# 3                      [dplyr, dplyr, dplyr, tidyr, tidyr]
# 4        [causaldata, DAAG, Ecdat, Ecdat, HSAUR, HSAUR,...
# 5        [DAAG, DAAG, DAAG, datasets, datasets, quantre...
# 6        [COUNT, COUNT, DAAG, datasets, datasets, datas...
# ...                                                    ...
# 310388                                         [stevedata]
# 336776                                      [nycflights13]
# 348532                                         [stevedata]
# 372864                                        [mosaicData]
# 1414593                                        [openintro]
#
#                                                       Item  \
# Rows
# 2        [jma.cojo, fish_oil_18, smiths, ChemoTHC, Migr...
# 3        [band_instruments, band_instruments2, band_mem...
# 4        [snow, rareplants, coolingFromNuclearWar, poli...
# ...

# %%
result = pd.concat([dt1,dt2],axis=0) #concatination of two dataframes

# %%
result
# Out:
#     order_id  quantity                              item_name  \
# 0        1.0       1.0           Chips and Fresh Tomato Salsa
# 1        1.0       1.0                                   Izze
# 2        1.0       1.0                       Nantucket Nectar
# 3        1.0       1.0  Chips and Tomatillo-Green Chili Salsa
# 4        2.0       2.0                           Chicken Bowl
# ..       ...       ...                                    ...
# 15       NaN       NaN                                    NaN
# 16       NaN       NaN                                    NaN
# 17       NaN       NaN                                    NaN
# 18       NaN       NaN                                    NaN
# 19       NaN       NaN                                    NaN
#
#                                    choice_description  item_price  \
# 0                                                 NaN        2.39
# 1                                        [Clementine]        3.39
# ...
